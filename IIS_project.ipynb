# %%
from google.cloud import bigquery
import pandas as pd

# %%
import os

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"E:\2026\Profile\shreeya-bigquery-analytics-lab-7e934b24f6e9.json"

# %%
client = bigquery.Client()

# %%
dataset_ref = client.dataset("iis_practise", project = "shreeya-bigquery-analytics-lab")

# %%
data_set= client.get_dataset(dataset_ref)

# %%
tables = list(client.list_tables(data_set))
for table in tables:
    print(table.table_id)
# Out:
# sales_lines_clean

# %%
table_ref = dataset_ref.table("sales_lines_clean")
table = client.get_table(table_ref)

# %%
client.list_rows(table, max_results=10).to_dataframe()
# Out:
#    int64_field_0  order_id  user_id  order_dow  order_hour_of_day  \
# 0        9059250   2886771    57384          5                  9
# 1        9059326    679181    57384          2                 17
# 2        1682139    445788    10844          6                  6
# 3        5926473   3226347    37753          6                  8
# 4        5925778   2551247    37753          6                 15
# 5       29257671   2905366   185818          4                 15
# 6       24933776   2715232   158307          5                 16
# 7       26682308   1836421   169655          5                  9
# 8       29145818    651170   185129          4                 13
# 9         923774   2919299     5956          2                 14
#
#    days_since_prior_order  product_id                            product_name  \
# 0                       6       31609        100% beef jalapeno cheeseburgers
# 1                       1       31609        100% beef jalapeno cheeseburgers
# ...

# %%
query = """select COUNT(*) AS total_rows
        FROM `shreeya-bigquery-analytics-lab.iis_practise.sales_lines_clean`"""
rows_count = print(client.query(query).to_dataframe())
# Out:
#    total_rows
# 0    32434489
# C:\Users\shree\.conda\envs\py312\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
query = """
SELECT column_name
FROM `shreeya-bigquery-analytics-lab.iis_practise.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'sales_lines_clean'

"""
cols_df = client.query(query).to_dataframe()
print(cols_df)
# Out:
# C:\Users\shree\.conda\envs\py312\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                column_name
# 0            int64_field_0
# 1                 order_id
# 2                  user_id
# 3                order_dow
# 4        order_hour_of_day
# 5   days_since_prior_order
# 6               product_id
# 7             product_name
# 8            department_id
# 9               department
# 10                     qty

# %%
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#    int64_field_0  order_id  user_id  order_dow  order_hour_of_day  \
# 0        9059250   2886771    57384          5                  9
# 1        9059326    679181    57384          2                 17
# 2        1682139    445788    10844          6                  6
# 3        5926473   3226347    37753          6                  8
# 4        5925778   2551247    37753          6                 15
#
#    days_since_prior_order  product_id                         product_name  \
# 0                       6       31609     100% beef jalapeno cheeseburgers
# 1                       1       31609     100% beef jalapeno cheeseburgers
# 2                       6       31609     100% beef jalapeno cheeseburgers
# 3                       7        1713  100% plant protein beastley sliders
# 4                       7        1713  100% plant protein beastley sliders
#
#    department_id department  qty
# 0              1     frozen    1
# 1              1     frozen    1
# ...

# %%
query = """ SELECT department,  order_dow, COUNT(1) AS products_sold
              FROM `shreeya-bigquery-analytics-lab.iis_practise.sales_lines_clean`
              GROUP BY department, order_dow """
count_of_items = print(client.query(query).to_dataframe())
# Out:
# C:\Users\shree\.conda\envs\py312\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#      department  order_dow  products_sold
# 0         other          3           4602
# 1        bakery          1         204386
# 2     beverages          6         341653
# 3     beverages          3         344815
# 4          pets          3          12589
# ..          ...        ...            ...
# 142   breakfast          0         127162
# 143  dairy eggs          4         635983
# 144   household          6         102601
# 145     missing          4           8174
# 146     missing          0          13220
#
# [147 rows x 3 columns]

# %%
df = pd.read_csv("sales_lines_clean")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df = pd.read_csv("sales_lines_clean")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
